# %%
import pandas as pd

# %%
data = pd.read_csv("U.S._Chronic_Disease_Indicators__CDI_.csv")
data.head()
# Out:
# c:\users\ishwar gautam\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource    Topic  \
# 0       2015     2015           AK       Alaska      YRBSS  Alcohol
# 1       2015     2015           AL      Alabama      YRBSS  Alcohol
# 2       2015     2015           AR     Arkansas      YRBSS  Alcohol
# 3       2015     2015           AZ      Arizona      YRBSS  Alcohol
# 4       2015     2015           CA   California      YRBSS  Alcohol
#
#                   Question Response DataValueUnit     DataValueType  ...  \
# 0  Alcohol use among youth      NaN             %  Crude Prevalence  ...
# 1  Alcohol use among youth      NaN             %  Crude Prevalence  ...
# ...

# %%
data.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# Response                      object
# DataValueUnit                 object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2       object
# Stratification2               object
# StratificationCategory3       object
# Stratification3               object
# GeoLocation                   object
# ResponseID                    object
# LocationID                     int64
# ...

# %%
data.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %%
data.shape
# Out:
# (406480, 34)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406480 entries, 0 to 406479
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  406480 non-null  int64
#  1   YearEnd                    406480 non-null  int64
#  2   LocationAbbr               406480 non-null  object
#  3   LocationDesc               406480 non-null  object
#  4   DataSource                 406480 non-null  object
#  5   Topic                      406480 non-null  object
#  6   Question                   406480 non-null  object
#  7   Response                   79323 non-null   object
#  8   DataValueUnit              375783 non-null  object
#  9   DataValueType              406480 non-null  object
#  10  DataValue                  300289 non-null  object
#  11  DataValueAlt               276138 non-null  float64
#  12  DataValueFootnoteSymbol    188067 non-null  object
# ...

# %%
data.describe()
# Out:
#            YearStart        YearEnd  DataValueAlt  LowConfidenceLimit  \
# count  406480.000000  406480.000000  2.761380e+05       248467.000000
# mean     2012.700807    2012.752052  7.448321e+02           49.889879
# std         1.585295       1.511674  1.819974e+04           83.926238
# min      2001.000000    2001.000000  0.000000e+00            0.200000
# 25%      2011.000000    2012.000000  1.890000e+01           13.000000
# 50%      2013.000000    2013.000000  4.170000e+01           31.100000
# 75%      2014.000000    2014.000000  7.120000e+01           57.400000
# max      2016.000000    2016.000000  3.967333e+06         1293.900000
#
#        HighConfidenceLimit     LocationID
# count        248467.000000  406480.000000
# mean             62.745047      30.994379
# std              96.159102      17.691045
# min               0.420000       1.000000
# 25%              20.100000      17.000000
# 50%              45.500000      30.000000
# ...

# %%
data.describe(include="object")
# Out:
#        LocationAbbr LocationDesc DataSource     Topic  \
# count        406480       406480     406480    406480
# unique           55           55         33        17
# top              KY   New Jersey      BRFSS  Diabetes
# freq           7827         7827     299921     67342
#
#                             Question Response DataValueUnit     DataValueType  \
# count                         406480    79323        375783            406480
# unique                           204        1            14                19
# top     Mortality from heart failure                      %  Crude Prevalence
# freq                            6136    79323        280119            150281
#
#        DataValue DataValueFootnoteSymbol  ... ResponseID TopicID QuestionID  \
# count     300289                  188067  ...      79323  406480     406480
# unique     20311                      19  ...          1      17        201
# ...

# %%
data.count()
# Out:
# YearStart                    406480
# YearEnd                      406480
# LocationAbbr                 406480
# LocationDesc                 406480
# DataSource                   406480
# Topic                        406480
# Question                     406480
# Response                      79323
# DataValueUnit                375783
# DataValueType                406480
# DataValue                    300289
# DataValueAlt                 276138
# DataValueFootnoteSymbol      188067
# DatavalueFootnote            187901
# LowConfidenceLimit           248467
# HighConfidenceLimit          248467
# StratificationCategory1      406480
# Stratification1              406480
# StratificationCategory2       79323
# Stratification2               79323
# StratificationCategory3       79323
# Stratification3               79323
# GeoLocation                  403864
# ResponseID                    79323
# LocationID                   406480
# TopicID                      406480
# ...

# %%
data['YearStart'].value_counts()
# Out:
# 2013    85913
# 2012    75796
# 2014    75524
# 2011    74593
# 2015    64046
# 2010    24965
# 2009     2771
# 2008     2604
# 2016      109
# 2001      104
# 2007       55
# Name: YearStart, dtype: int64

# %%
data['YearStart'].value_counts(bins=10)
# Out:
# (2011.5, 2013.0]      161709
# (2013.0, 2014.5]       75524
# (2010.0, 2011.5]       74593
# (2014.5, 2016.0]       64155
# (2008.5, 2010.0]       27736
# (2007.0, 2008.5]        2604
# (2000.984, 2002.5]       104
# (2005.5, 2007.0]          55
# (2004.0, 2005.5]           0
# (2002.5, 2004.0]           0
# Name: YearStart, dtype: int64

# %%
data['DataValueType'].value_counts(dropna=False, ascending=True)
# Out:
# Prevalence                                                              52
# Commercial host (dram shop) liability status for alcohol service       106
# Per capita alcohol consumption                                         107
# Local control of the regulation of alcohol outlet density              109
# US Dollars                                                             321
# Adjusted by age, sex, race and ethnicity                               520
# Yes/No                                                                 918
# Percent                                                               1209
# Average Annual Crude Rate                                             1664
# Average Annual Number                                                 1664
# Average Annual Age-adjusted Rate                                      1664
# Median                                                                2822
# ...

# %%
data['DataValueType'].value_counts(dropna=True, ascending=False)
# Out:
# Crude Prevalence                                                    150281
# Age-adjusted Prevalence                                             128577
# Number                                                               32419
# Crude Rate                                                           31311
# Age-adjusted Rate                                                    31311
# Age-adjusted Mean                                                    10875
# Mean                                                                 10550
# Median                                                                2822
# Average Annual Age-adjusted Rate                                      1664
# Average Annual Number                                                 1664
# Average Annual Crude Rate                                             1664
# Percent                                                               1209
# ...

# %%
ky_only = data['LocationAbbr']=='KY'
data[ky_only]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc  \
# 17           2015     2015           KY     Kentucky
# 69           2015     2015           KY     Kentucky
# 249          2015     2015           KY     Kentucky
# 250          2015     2015           KY     Kentucky
# 251          2015     2015           KY     Kentucky
# ...           ...      ...          ...          ...
# 406220       2008     2012           KY     Kentucky
# 406221       2008     2012           KY     Kentucky
# 406376       2008     2012           KY     Kentucky
# 406377       2008     2012           KY     Kentucky
# 406378       2008     2012           KY     Kentucky
#
#                                  DataSource    Topic  \
# 17                                    YRBSS  Alcohol
# 69                                    YRBSS  Alcohol
# 249                                   BRFSS  Alcohol
# 250                                   BRFSS  Alcohol
# 251                                   BRFSS  Alcohol
# ...

# %%
data['Response'].value_counts()
# Out:
#      79323
# Name: Response, dtype: int64

# %%
data['Response'].value_counts(dropna=False)
# Out:
# NaN    327157
#         79323
# Name: Response, dtype: int64

# %%
data['DatavalueFootnote'].value_counts(dropna=False,ascending=True)
# Out:
# Per capita alcohol consumption was calculated using (1) alcohol beverage sales data, either collected directly from states or provided by beverage industry sources (numerator); and (2) population data from the U.S. Census Bureau (denominator).                                                                                                                                                                                                                                                             1
# DC was not rated for this measure because the measure addresses state versus local authority and does not apply to the District of Columbia                                                                                                                                                                                                                                                                                                                                                                     1
# ...

# %%
data.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Question                          0
# Response                     327157
# DataValueUnit                 30697
# DataValueType                     0
# DataValue                    106191
# DataValueAlt                 130342
# DataValueFootnoteSymbol      218413
# DatavalueFootnote            218579
# LowConfidenceLimit           158013
# HighConfidenceLimit          158013
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2      327157
# Stratification2              327157
# StratificationCategory3      327157
# Stratification3              327157
# GeoLocation                    2616
# ResponseID                   327157
# LocationID                        0
# TopicID                           0
# ...

# %%
data['GeoLocation'].isnull().sum()
# Out:
# 2616

# %%
data.corr(method='pearson')
# Out:
#                      YearStart   YearEnd  DataValueAlt  LowConfidenceLimit  \
# YearStart             1.000000  0.959956     -0.033925           -0.131716
# YearEnd               0.959956  1.000000     -0.031133           -0.128807
# DataValueAlt         -0.033925 -0.031133      1.000000            0.994804
# LowConfidenceLimit   -0.131716 -0.128807      0.994804            1.000000
# HighConfidenceLimit  -0.121733 -0.123540      0.993999            0.977918
# LocationID            0.018818  0.017062      0.019338           -0.007849
#
#                      HighConfidenceLimit  LocationID
# YearStart                      -0.121733    0.018818
# YearEnd                        -0.123540    0.017062
# DataValueAlt                    0.993999    0.019338
# LowConfidenceLimit              0.977918   -0.007849
# HighConfidenceLimit             1.000000   -0.009414
# LocationID                     -0.009414    1.000000

# %%
data.loc[10:15,["YearStart","YearEnd"]]
# Out:
#     YearStart  YearEnd
# 10       2015     2015
# 11       2015     2015
# 12       2015     2015
# 13       2015     2015
# 14       2015     2015
# 15       2015     2015

# %%
new_data = data[data.LocationAbbr.apply(lambda state: state == 'NV')]

# %%
new_data.tail(3)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc         DataSource  \
# 406424       2008     2012           NV       Nevada  Death certificate
# 406425       2008     2012           NV       Nevada  Death certificate
# 406426       2008     2012           NV       Nevada  Death certificate
#
#          Topic             Question Response DataValueUnit  \
# 406424  Cancer  Melanoma, mortality      NaN   per 100,000
# 406425  Cancer  Melanoma, mortality      NaN   per 100,000
# 406426  Cancer  Melanoma, mortality      NaN           NaN
#
#                            DataValueType  ... LocationID  TopicID QuestionID  \
# 406424  Average Annual Age-adjusted Rate  ...         32      CAN     CAN9_2
# 406425         Average Annual Crude Rate  ...         32      CAN     CAN9_2
# 406426             Average Annual Number  ...         32      CAN     CAN9_2
#
#          DataValueTypeID  StratificationCategoryID1  StratificationID1  \
# ...

# %%
pd.crosstab(data['Topic'], new_data['YearEnd'])
# Out:
# YearEnd                                          2001  2007  2008  2010  2011  \
# Topic
# Alcohol                                             0     0     0    25   102
# Arthritis                                           0     0     0     0   128
# Asthma                                              0     0     0    57   110
# Cancer                                              0     0     0     0     0
# Cardiovascular Disease                              0     0     0   177   255
# Chronic Kidney Disease                              0     0     0    28    44
# Chronic Obstructive Pulmonary Disease               0     0     0   162   176
# Diabetes                                            0     0     0    97   251
# Disability                                          0     0     0     0     0
# Immunization                                        0     0     0     0    16
# Mental Health                                       0     0     0     0    23
# ...

# %%
pd.crosstab(data['Topic'], new_data['YearEnd'],margins=True)
# Out:
# YearEnd                                          2001  2007  2008  2010  2011  \
# Topic
# Alcohol                                             0     0     0    25   102
# Arthritis                                           0     0     0     0   128
# Asthma                                              0     0     0    57   110
# Cancer                                              0     0     0     0     0
# Cardiovascular Disease                              0     0     0   177   255
# Chronic Kidney Disease                              0     0     0    28    44
# Chronic Obstructive Pulmonary Disease               0     0     0   162   176
# Diabetes                                            0     0     0    97   251
# Disability                                          0     0     0     0     0
# Immunization                                        0     0     0     0    16
# Mental Health                                       0     0     0     0    23
# ...

# %%
pd.crosstab(data['Topic'], new_data['Response'], margins=True)
# Out:
# Response                                      All
# Topic
# Alcohol                                 120   120
# Asthma                                  192   192
# Cardiovascular Disease                  696   696
# Chronic Kidney Disease                  120   120
# Chronic Obstructive Pulmonary Disease   312   312
# Diabetes                                336   336
# All                                    1776  1776
